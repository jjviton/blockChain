# %% [markdown]
# # BlockChain sencilla
#
# Se crea un bloque con parametros y un array de datos (data), luego se hace __mina__ el Hash (minar es buscar el hash
# que cumple da condición que nos imponemos, la dicicultad (diff); buscamos un hash que empize por x ceros, o lo que es lo mismo que sea menor de un valor(_2elevado_a_(256-diff)
#
# Este es un metodo Digest, no tiene criptografica ni usa claves. En el SAM de Galicia, sí que usa una clave en cada minado.
# Pare temas de IOT podemos incorporar una clave que firme el hash final. Clave diversificada por dispositivo.
# ***
# Github de la base del código __[code github](https://github.com/howCodeORG/Simple-Python-Blockchain/blob/master/blockchain.py)__
#
# __[Makdown info](https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed)__
#
# __ToDo__
#
# <font color=red>
# Voy a investigar como añadir criptografía simétria/asimétrica para mejorar la seguridad del HASH</font>
#
# _J3Viton_

# %%
import datetime

# %%
import hashlib

# %%
class Block:
    blockNo = 0
    data = None
    next = None
    hash = None
    nonce = 0
    previous_hash = 0x0
    timestamp = datetime.datetime.now()

    def __init__(self, data):
        self.data = data

    def hash(self):
        h = hashlib.sha256()
        h.update(
        str(self.nonce).encode('utf-8') +
        str(self.data).encode('utf-8') +
        str(self.previous_hash).encode('utf-8') +
        str(self.timestamp).encode('utf-8') +
        str(self.blockNo).encode('utf-8')
        )
        return h.hexdigest()

    def __str__(self):
        return "Block Hash: " + str(self.hash()) + "\nBlockNo: " + str(self.blockNo) + "\nBlock Data: " + str(self.data) + "\nHashes = Nonce: " + str(self.nonce) + "\n--------------"

# %%
class Blockchain:

    diff = 21
    maxNonce = 2**32
    target = 2 ** (256-diff)  # defino el número más grande para el hash, entonces los primeros digitos son cero

    block = Block("Genesis")
    dummy = head = block

    def add(self, block):

        block.previous_hash = self.block.hash()
        block.blockNo = self.block.blockNo + 1

        self.block.next = block
        self.block = self.block.next

    def mine(self, block):
        for n in range(self.maxNonce):
            if int(block.hash(), 16) <= self.target:
                self.add(block)
                print(block)
                break
            else:
                block.nonce += 1

# %% [markdown]
# # Aquí empieza la minería:
#
# ### _diff_ es es parametro que marca la dificultad para encontrar el hash bueno.
#
# Algunos resultados:
# * Para __diff= 28__
#         1min 51s ± 24.1 s per loop (mean ± std. dev. of 7 runs, 3 loops each)
#
# * Para __diff= 23__
#         43s per loop
#
#
# %%time
# blockchain = Blockchain()
#
# #for n in range(5):
# n=5
# %timeit -n3 blockchain.mine(Block("Texto  " + str(n+1)))
# n=n+1
#
# %% time nos da el tiempo de ejecucion de una celda.

# %%
# %%time
blockchain = Blockchain()
for n in range(5):  
    blockchain.mine(Block("Texto  " + str(n+1)))
# Out:
# Block Hash: 7c0bc0def37f95e0390d8ac4d340854dcfa19ae5a28b2f0a9f8eec468034cd0f
# BlockNo: 1
# Block Data: Texto  1
# Hashes = Nonce: 4140567
# --------------
# Block Hash: b80c6f09495c132c46aa802b2c8e201c0d2209951d8a8522134db7f283181a62
# BlockNo: 2
# Block Data: Texto  2
# Hashes = Nonce: 3201694
# --------------
# Block Hash: def482c94fa5bb9f30ec75cacfaccb79ab85f9092d4d3f5fce0612975daec9e0
# BlockNo: 3
# Block Data: Texto  3
# Hashes = Nonce: 193864
# --------------
# Block Hash: 0929e9c8ae04a05b41952b5574ff1340cd5b2176d12c8675f424ee07a500ba61
# BlockNo: 4
# Block Data: Texto  4
# Hashes = Nonce: 79885
# --------------
# Block Hash: 7a16c6bdfa8df0e99ce2eb30b1f91be3b70a0dd242a472f20c23f98fe63a8201
# BlockNo: 5
# Block Data: Texto  5
# Hashes = Nonce: 2449271
# --------------
# Wall time: 1min 1s

# %%
while blockchain.head != None:
    print(blockchain.head)
    blockchain.head = blockchain.head.next
# Out:
# Block Hash: 234e5e85437c09b9e8f44984a65a5dce8fdaa41398ef5893f01ec3ddecd687b5
# BlockNo: 0
# Block Data: Genesis
# Hashes = Nonce: 0
# --------------
# Block Hash: 7c0bc0def37f95e0390d8ac4d340854dcfa19ae5a28b2f0a9f8eec468034cd0f
# BlockNo: 1
# Block Data: Texto  1
# Hashes = Nonce: 4140567
# --------------
# Block Hash: b80c6f09495c132c46aa802b2c8e201c0d2209951d8a8522134db7f283181a62
# BlockNo: 2
# Block Data: Texto  2
# Hashes = Nonce: 3201694
# --------------
# Block Hash: def482c94fa5bb9f30ec75cacfaccb79ab85f9092d4d3f5fce0612975daec9e0
# BlockNo: 3
# Block Data: Texto  3
# Hashes = Nonce: 193864
# --------------
# Block Hash: 0929e9c8ae04a05b41952b5574ff1340cd5b2176d12c8675f424ee07a500ba61
# BlockNo: 4
# Block Data: Texto  4
# Hashes = Nonce: 79885
# --------------
# Block Hash: 7a16c6bdfa8df0e99ce2eb30b1f91be3b70a0dd242a472f20c23f98fe63a8201
# BlockNo: 5
# Block Data: Texto  5
# Hashes = Nonce: 2449271
# --------------
